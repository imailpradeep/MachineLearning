# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df0 = pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv', header = 1)

# %% [markdown]
# Open up csv file and see the table

# %%
df0.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %%
df0.shape
# Out:
# (246, 14)

# %%
df0.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %% [markdown]
# Open file in excel and we see that there are three rows in between and two regions separated by it.
# in the code below we open dataframe using the wand stick in top right corner of the output and go to the line 122,123
# unlike in excel we do not have an empty line

# %%
df0
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
df1 =df0
df1.drop([122,123],inplace = True)
#we put inplace = True so that changes are made in df1 itself, without it another df is returned
#but df1 remains same

# %%
df1
#check if lines 122,123 has no issues
#note that theses two line numbers are missing
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
df1.shape
# Out:
# (244, 14)

# %%
region = []
for i in range(244):
  if i<122:
    region.append('bejaia region')
  else:
    region.append('sidi-bel abbes region')

# %%
df1['Region']= region

# %%
df1.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes           Region
# 0  not fire     bejaia region
# 1  not fire     bejaia region
# 2  not fire     bejaia region
# 3  not fire     bejaia region
# 4  not fire     bejaia region

# %%
df1.tail()
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes                   Region
# 241  6.5       fire     sidi-bel abbes region
# 242    0   not fire     sidi-bel abbes region
# 243  0.2   not fire     sidi-bel abbes region
# 244  0.7   not fire     sidi-bel abbes region
# 245  0.5  not fire      sidi-bel abbes region

# %%
df1.columns
##note the spaces in the column/feature headings
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
df1.info()
#note that even int and float are all objects
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 244 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    object
#  4    RH          244 non-null    object
#  5    Ws          244 non-null    object
#  6   Rain         244 non-null    object
#  7   FFMC         244 non-null    object
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  FWI          244 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       244 non-null    object
# dtypes: object(15)
# memory usage: 30.5+ KB

# %%
df1.isnull().sum()
#ignore one null value for now, we can remove the row later if required
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        1
# Region         0
# dtype: int64

# %%
df1.columns =[index.strip() for index in df1.columns]
#strip spaces from before and after the headings

# %%
#df1 = df1.astype({'day':'int','month':'int','year':'int','Temperature':'int','RH':'int','Ws':'int','Rain':'float','FFMC':'float','DMC':'float','ISI':'float','BUI':'float', 'DC':'float', 'FWI': 'float'})
#gives error because DC and FWI has space inbetween (14.6 9) and string values('Fire   ') respectively
# luckily its only one/same value in each column so we can correct it manually
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-52b664f3247b> in <module>
# ----> 1 df1 = df1.astype({'day':'int','month':'int','year':'int','Temperature':'int','RH':'int','Ws':'int','Rain':'float','FFMC':'float','DMC':'float','ISI':'float','BUI':'float', 'DC':'float', 'FWI': 'float'})
#       2 #gives error because DC and FWI has space inbetween (14.6 9) and string values('Fire   ') respectively
#       3 # luckily its only one value in each column so we can correct it manually
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5797                 if col_name in dtype:
#    5798                     results.append(
# -> 5799                         col.astype(dtype=dtype[col_name], copy=copy, errors=errors)
#    5800                     )
#    5801                 else:
#
# ...

# %%
df1 = df1.astype({'day':'int','month':'int','year':'int','Temperature':'int','RH':'int','Ws':'int'})
# convert object dtypes to int where needed

# %%
df1 = df1.astype({'Rain':'float','FFMC':'float','DMC':'float','ISI':'float','BUI':'float'})
# convert float values from dtypes 'object' to 'float'

# %%
df1.DC = [float(i) if i!='14.6 9' else float(14.69) for i in df1.DC]
df1.FWI = [float(i) if i!='fire   ' else float(0) for i in df1.FWI]
#replace '14.6 9' as 14.69 and 'fire   ' as 0

# %%
df1['FWI'].mean()
#finding mean after everything in df1['FWI'] is converted to float
#so that we replace loc of 'fire   ' with mean for accuracy
# Out:
# 7.006557377049181

# %%
df0.loc[df0['FWI'].str.endswith("e   ")]
# Out:
#     day month  year Temperature  RH  Ws Rain  FFMC   DMC      DC   ISI   BUI  \
# 167  14    07  2012          37  37  18  0.2  88.9  12.9  14.6 9  12.5  10.4
#
#          FWI Classes                 Region
# 167  fire        NaN  sidi-bel abbes region

# %%
# IGNORE THIS FOR NOW - I WISH TO REPLACE ALL fire    VALUES WITH MEAN FWI.
#find row number of 'fire   ' using original dataset 
'''
fire = []
for i in df0['FWI']:
  print(df0.iloc)


  if df0['FWI'] == 'fire   ':
    fire.append(i)

#df0.loc[df0['FWI'].str.endswith("e   ")]
fire
'''
# Out:
# '\nfire = []\nfor i in df0[\'FWI\']:\n  print(df0.iloc)\n\n\n  if df0[\'FWI\'] == \'fire   \':\n    fire.append(i)\n\n#df0.loc[df0[\'FWI\'].str.endswith("e   ")]\nfire\n'

# %%
df1.iloc[165] #iloc is 165 because the header is at 1 and not at 0
# Out:
# day                               14
# month                              7
# year                            2012
# Temperature                       37
# RH                                37
# Ws                                18
# Rain                             0.2
# FFMC                            88.9
# DMC                             12.9
# DC                             14.69
# ISI                             12.5
# BUI                             10.4
# FWI                              0.0
# Classes                          NaN
# Region         sidi-bel abbes region
# Name: 167, dtype: object

# %%
df1.iloc[165,12]= df1['FWI'].mean()
#replacing one FWI value from 0 to mean value
#I do not wish to replace all 0 with mean as some data may be 0 and not assigned value is 0

# %%
df1['Classes'].mode()
# Out:
# 0    fire
# dtype: object

# %%
# I am replacing NAN value with mode, otherwise I can delete the entire row first itself 
# deleting would hace saved a lot of time
df1.iloc[165,13]= df1['Classes'].mode()

# %%
df1.iloc[165]
#checking
# Out:
# day                               14
# month                              7
# year                            2012
# Temperature                       37
# RH                                37
# Ws                                18
# Rain                             0.2
# FFMC                            88.9
# DMC                             12.9
# DC                             14.69
# ISI                             12.5
# BUI                             10.4
# FWI                         7.035246
# Classes                      fire
# Region         sidi-bel abbes region
# Name: 167, dtype: object

# %% [markdown]
# **UNIVARIENT** **ANALYSIS**

# %%
categorical_columns = [i  for i in df1.columns if df1[i].dtypes=='O' ]
categorical_columns
# Out:
# ['Classes', 'Region']

# %%
numerical_columns = [i  for i in df1.columns if df1[i].dtypes!='object' ]
numerical_columns
# Out:
# ['day',
#  'month',
#  'year',
#  'Temperature',
#  'RH',
#  'Ws',
#  'Rain',
#  'FFMC',
#  'DMC',
#  'DC',
#  'ISI',
#  'BUI',
#  'FWI']

# %%
df1.dtypes
# Out:
# day              int64
# month            int64
# year             int64
# Temperature      int64
# RH               int64
# Ws               int64
# Rain           float64
# FFMC           float64
# DMC            float64
# DC             float64
# ISI            float64
# BUI            float64
# FWI            float64
# Classes         object
# Region          object
# dtype: object

# %%
df1.isnull().sum().sum()
# no need to use df1 = df1.fillna(0)
# Out:
# 0

# %%
plt.figure(figsize=(15,15))
plt.suptitle("UNIVARIATE analysis of Numeric data", fontsize = 20)
for i in range(0,len(numerical_columns)):
  plt.subplot(5,3,i+1)
  sns.kdeplot(x = df1[numerical_columns[i]], shade = True, color = 'g')
  plt.xlabel(numerical_columns[i])
 # plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# some have skew hence need to remove outliers

# %%
df1.corr()
# Out:
#                       day         month  year  Temperature        RH  \
# day          1.000000e+00  2.232788e-17   NaN     0.095772 -0.074209
# month        2.232788e-17  1.000000e+00   NaN    -0.059017 -0.037884
# year                  NaN           NaN   NaN          NaN       NaN
# Temperature  9.577222e-02 -5.901677e-02   NaN     1.000000 -0.654443
# RH          -7.420934e-02 -3.788419e-02   NaN    -0.654443  1.000000
# Ws           4.700086e-02 -4.144673e-02   NaN    -0.278132  0.236084
# Rain        -1.122654e-01  3.532207e-02   NaN    -0.326786  0.222968
# FFMC         2.240321e-01  1.557668e-02   NaN     0.677491 -0.645658
# DMC          4.915710e-01  6.817778e-02   NaN     0.483105 -0.405133
# DC           5.279300e-01  1.276691e-01   NaN     0.370511 -0.220344
# ISI          1.777266e-01  6.168011e-02   NaN     0.607551 -0.690637
# BUI          5.172292e-01  8.582162e-02   NaN     0.455504 -0.348587
# FWI          3.507523e-01  8.260441e-02   NaN     0.564599 -0.577577
#
# ...

# %%
df2 = df1.drop(['year'], axis = 1)

# %%
df2.corr()
# Out:
#                       day         month  Temperature        RH        Ws  \
# day          1.000000e+00  2.232788e-17     0.095772 -0.074209  0.047001
# month        2.232788e-17  1.000000e+00    -0.059017 -0.037884 -0.041447
# Temperature  9.577222e-02 -5.901677e-02     1.000000 -0.654443 -0.278132
# RH          -7.420934e-02 -3.788419e-02    -0.654443  1.000000  0.236084
# Ws           4.700086e-02 -4.144673e-02    -0.278132  0.236084  1.000000
# Rain        -1.122654e-01  3.532207e-02    -0.326786  0.222968  0.170169
# FFMC         2.240321e-01  1.557668e-02     0.677491 -0.645658 -0.163255
# DMC          4.915710e-01  6.817778e-02     0.483105 -0.405133 -0.001246
# DC           5.279300e-01  1.276691e-01     0.370511 -0.220344  0.076253
# ISI          1.777266e-01  6.168011e-02     0.607551 -0.690637  0.015248
# BUI          5.172292e-01  8.582162e-02     0.455504 -0.348587  0.029756
# FWI          3.507523e-01  8.260441e-02     0.564599 -0.577577  0.032315
#
# ...

# %%
plt.figure(figsize =(15,15))
sns.heatmap(df2.corr(), annot =True)
  plt.show()

# %%
sns.pairplot(df2)

# %%
df2.hist(figsize=(10,10), color ='b')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f04758eac90>,
# ...
#       dtype=object)

# %%
sns.lineplot(x ='Temperature', y ='Rain', data = df2, color = 'b')

# %%
sns.jointplot(x ='Temperature', y ='Rain', data = df2, color = 'b')

# %%
sns.jointplot(x ='Temperature', y ='month', data = df2, color = 'b')

# %%
df2.columns
# Out:
# Index(['day', 'month', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC',
#        'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
#above plot is not vert correct hence getting date value by combining day month and year
#using df1 as we already dropped year in df2
df2['date'] = pd.to_datetime(df1[['day','month', 'year']])
#df2.drop(['day','month'], axis =1, inplace =True)

# %%
sns.boxplot(x= 'Region', y = 'Temperature', data = df2)

# %%
 sns.countplot(df2['Region'])
 #count of observations
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
binary_region = []
for i in df2['Region']:
  if i == 'bejaia region':
     binary_region.append(1)
  else:
    binary_region.append(0)

df2['binary_region']=binary_region

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 244 entries, 0 to 245
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   day            244 non-null    int64
#  1   month          244 non-null    int64
#  2   Temperature    244 non-null    int64
#  3   RH             244 non-null    int64
#  4   Ws             244 non-null    int64
#  5   Rain           244 non-null    float64
#  6   FFMC           244 non-null    float64
#  7   DMC            244 non-null    float64
#  8   DC             244 non-null    float64
#  9   ISI            244 non-null    float64
#  10  BUI            244 non-null    float64
#  11  FWI            244 non-null    float64
#  12  Classes        244 non-null    object
#  13  Region         244 non-null    object
#  14  date           244 non-null    datetime64[ns]
#  15  binary_region  244 non-null    int64
# dtypes: datetime64[ns](1), float64(7), int64(6), object(2)
# ...

# %%
df2.drop(['Classes'],axis =1, inplace =True)
#classes is the output

# %% [markdown]
# We are putting the below as independent variables

# %%
x =pd.DataFrame(df2, columns = ['RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI',
       'FWI', 'binary_region'])

# %% [markdown]
# Temperature is the dependent variable
# df2['Classes'] - Fire and Not Fire - is not put as dependent variable as it is a categorical feature and will need logistic regression. Here we are doing linear regression using Temperature as it is continuous data

# %%
y =pd.DataFrame(df2, columns = ['Temperature'])

# %%
x
# Out:
#      RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  binary_region
# 0    57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5              1
# 1    61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4              1
# 2    82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1              1
# 3    89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0              1
# 4    77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5              1
# ..   ..  ..   ...   ...   ...   ...  ...   ...  ...            ...
# 241  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5              0
# 242  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0              0
# 243  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2              0
# 244  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7              0
# 245  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5              0
#
# [244 rows x 10 columns]

# %%
y
# Out:
#      Temperature
# 0             29
# 1             29
# 2             26
# 3             25
# 4             27
# ..           ...
# 241           30
# 242           28
# 243           27
# 244           24
# 245           24
#
# [244 rows x 1 columns]

# %% [markdown]
# Training and Testing data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
x_train.shape
# Out:
# (163, 10)

# %%
x_test.shape
# Out:
# (81, 10)

# %%
y_train.shape
# Out:
# (163, 1)

# %%
y_test.shape
# Out:
# (81, 1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler
# Out:
# StandardScaler()

# %% [markdown]
# Feature scaling is a method used to normalize the range of independent variables or features of data. We need to perform Feature Scaling when we are dealing with Gradient Descent Based algorithms (Linear and Logistic Regression, Neural Network) and Distance-based algorithms (KNN, K-means, SVM) as these are very sensitive to the range of the data points. Scaling inputs helps to avoid the situation, when one or several features dominate others in magnitude, as a result, the model hardly picks up the contribution of the smaller scale variables, even if they are strong. Puts values between [-1,1]

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 0.60473755, -0.58758991,  2.96784752, ..., -0.94680281,
#         -0.91800496, -0.99388373],
#        [ 0.14008735, -2.50313301,  0.22039416, ..., -0.3609316 ,
#         -0.8771745 , -0.99388373],
#        [ 0.47198035, -0.97069853, -0.03879955, ..., -0.77623271,
#         -0.90439481,  1.0061539 ],
#        ...,
#        [ 1.79955233, -0.97069853, -0.03879955, ..., -1.043212  ,
#         -0.97244557,  1.0061539 ],
#        [-0.25818425, -1.35380715,  1.7237177 , ..., -0.91713844,
#         -0.91800496, -0.99388373],
#        [ 0.73749474,  0.56173595,  0.06487794, ..., -0.98388327,
#         -0.91800496,  1.0061539 ]])

# %%
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(x_train, y_train)
reg
# Out:
# LinearRegression()

# %%
# coefficients
print(reg.coef_)
# Out:
# [[-1.39828755 -0.98541486  0.02536282  0.91405733  0.32697405  0.33174106
#    0.69982361  0.13321853 -0.70664005  0.07676552]]

# %%
#one of the coefficients is the intercpt <theta>0
print(reg.intercept_)
# Out:
# [32.26993865]

# %% [markdown]
# PREDICTION

# %%
# after learning from training data we use the 'reg' to predict
reg_pred = reg.predict(x_test)

# %%
reg_pred
# Out:
# array([[30.60463033],
#        [34.74040046],
#        [36.19344395],
#        [33.78396283],
#        [33.63071874],
#        [36.47350221],
#        [35.63604155],
#        [31.71839737],
#        [33.20387014],
#        [27.28785279],
#        [30.9068451 ],
#        [30.69873629],
#        [33.58403631],
#        [34.95659427],
#        [35.05023578],
#        [35.57028447],
#        [35.1104037 ],
#        [32.26985629],
#        [32.81208112],
#        [33.11210277],
#        [31.27611816],
#        [32.67792826],
#        [29.70412117],
#        [35.91903532],
#        [34.670719  ],
#        [35.22911072],
#        [33.98474061],
#        [35.32801886],
#        [33.79446949],
#        [35.35986188],
#        [29.92540683],
#        [21.95936302],
#        [30.82050802],
#        [27.68801191],
#        [27.0768838 ],
#        [28.9796488 ],
#        [28.48591179],
#        [31.41068572],
#        [33.77899921],
#        [32.35412403],
#        [31.09393832],
# ...

# %% [markdown]
# ASSUMPTION of LINEAR REGRESSION

# %%
#compare the predicted and y test data
plt.scatter(y_test,reg_pred )
plt.xlabel("Truth test data")
plt.ylabel("Predicted test data")
#this plot should not have any trend
# Out:
# Text(0, 0.5, 'Predicted test data')

# %% [markdown]
# Residuals
# Residuals is the difference in actual answer of test data and predicted answer.
# The kde plot of residuals should be gaussian curve
# Scatter plot of residual and predicted values should not have a trend

# %%
Residuals = y_test-reg_pred
Residuals
# Out:
#      Temperature
# 87      2.395370
# 238     0.259600
# 211    -0.193444
# 155    -0.783963
# 130     1.369281
# ..           ...
# 126     0.585359
# 112    -4.421610
# 235     0.056796
# 176    -1.369922
# 11     -3.702266
#
# [81 rows x 1 columns]

# %%
sns.displot(Residuals, kind = 'kde')

# %% [markdown]
# PERFORMANCE MATRIX
# how good is the prediction?

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, reg_pred)
# Out:
# 7.34479675722983

# %%
np.sqrt(mean_squared_error(y_test, reg_pred))
# Out:
# 2.7101285499455243

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, reg_pred)
# Out:
# 2.048121111019853

# %%
from sklearn.metrics import r2_score
R2 = r2_score(y_test, reg_pred)
R2
# Out:
# 0.4026525743233723

# %%
#Adjusted R2
AdjR2 = 1-(1-R2)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
AdjR2
# Out:
# 0.31731722779813976

# %% [markdown]
# **RIDGE REGRESSION**

# %%
from sklearn.linear_model import Ridge
ridge = Ridge()
ridge.fit(x_train, y_train)
# Out:
# Ridge()

# %%
ridge.coef_
# Out:
# array([[-1.38500059, -0.97596599,  0.01750551,  0.92173207,  0.27525249,
#          0.30326743,  0.58801124,  0.13029534, -0.53368835,  0.06633346]])

# %%
ridge.intercept_
# Out:
# array([32.26993865])

# %%
reg_pred = ridge.predict(x_test)
reg_pred
# Out:
# array([[30.54675842],
#        [34.75946485],
#        [36.19673953],
#        [33.77553976],
#        [33.63104305],
#        [36.52470374],
#        [35.56489601],
#        [31.71553664],
#        [33.22538737],
#        [27.31316129],
#        [30.92338162],
#        [30.69944916],
#        [33.60885112],
#        [34.95982514],
#        [35.02556244],
#        [35.56239744],
#        [35.03324109],
#        [32.24776767],
#        [32.80187414],
#        [33.13186786],
#        [31.27102997],
#        [32.69944575],
#        [29.72299285],
#        [35.88540139],
#        [34.61594461],
#        [35.20902382],
#        [33.96363297],
#        [35.37589367],
#        [33.77741914],
#        [35.3706177 ],
#        [29.92400092],
#        [22.05501537],
#        [30.82260339],
#        [27.72037931],
#        [27.0925724 ],
#        [28.99655941],
#        [28.50470007],
#        [31.36526971],
#        [33.74301365],
#        [32.34263053],
#        [31.08784853],
# ...

# %%
plt.scatter(x = y_test, y = reg_pred)
plt.xlabel("Truth data")
plt.ylabel("Predict data")
# Out:
# Text(0, 0.5, 'Predict data')

# %%
import matplotlib.pyplot as plt
from importlib import reload
plt=reload(plt)

# %%
residual = y_test-reg_pred
plt.scatter(x = reg_pred, y = residual)
plt.xlabel("Predicted data")
plt.ylabel("residual")
# Out:
# Text(0, 0.5, 'residual')

# %%
#Performance of tool
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, reg_pred)
# Out:
# 7.301703952337792

# %%
np.sqrt(mean_squared_error(y_test, reg_pred))
# Out:
# 2.702166529349698

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, reg_pred)
# Out:
# 2.0469852871973333

# %%
from sklearn.metrics import r2_score
ridge_r2 = r2_score(y_test, reg_pred)
ridge_r2
# Out:
# 0.40615728342810076

# %%
AdjR2 = 1- (1-ridge_r2)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
AdjR2
# Out:
# 0.32132260963211523

# %% [markdown]
# **Elastic_net Regression**

# %%
from sklearn.linear_model import ElasticNet
elastic = ElasticNet()

# %%
elastic.fit(x_train, y_train)
# Out:
# ElasticNet()

# %%
elastic.coef_
# Out:
# array([-0.71749256, -0.39459018, -0.        ,  0.63929697,  0.13121946,
#         0.        ,  0.29349157,  0.03304424,  0.19384395, -0.        ])

# %%
elastic.intercept_
# Out:
# array([32.26993865])

# %%
elastic_pred = elastic.predict(x_test)
elastic_pred
# Out:
# array([31.38039772, 33.8664514 , 34.99554528, 33.29330588, 33.16833499,
#        36.02579026, 33.07506764, 31.7745963 , 33.81694226, 29.40328773,
#        31.19922711, 31.25480219, 33.46186937, 33.86424415, 33.55931729,
#        34.29811886, 33.23361608, 32.14547249, 32.48765333, 33.1098492 ,
#        31.46326735, 32.84833493, 31.03296548, 34.14490166, 33.09401074,
#        33.72676365, 33.01378857, 34.7826692 , 32.81298446, 34.29647002,
#        30.68173242, 26.97700518, 31.07777089, 29.23456817, 28.89710394,
#        30.02104286, 29.59695384, 31.49975133, 32.70201872, 32.09044963,
#        31.45013497, 31.5018    , 34.06706429, 33.07503135, 30.50427114,
#        30.86272279, 33.41696388, 31.37661066, 32.23147809, 28.89666895,
#        29.55383527, 35.40217526, 30.6241244 , 35.2313038 , 32.85810207,
#        29.32442223, 31.30036336, 30.49602632, 32.61811897, 34.61550684,
#        32.44881213, 30.80246491, 32.59656903, 31.87206945, 32.10669959,
# ...

# %%
plt.scatter(y_test, elastic_pred)
plt.xlabel("truth data")
plt.ylabel("predicted data")
# Out:
# Text(0, 0.5, 'predicted data')

# %%
mean_squared_error(y_test, elastic_pred)
# Out:
# 6.666057080208148

# %%
np.sqrt(mean_squared_error(y_test, elastic_pred))
# Out:
# 2.5818708488629225

# %%
mean_absolute_error(y_test, elastic_pred)
# Out:
# 2.0127668975346973

# %%
r2 = r2_score(y_test, elastic_pred)
r2
# Out:
# 0.4578540199419171

# %%
AdjR2 = 1-(1-r2)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
AdjR2
# Out:
# 0.3804045942193338

# %% [markdown]
# DO LASSO properly

# %%
from sklearn import linear_model

lasso_reg = linear_model.Lasso(alpha=0.1)
lasso_reg.fit(x_train,y_train)
lasso_reg.score(x_test, y_test), lasso_reg.score(x_train, y_train)
# Out:
# (0.4316754605195562, 0.6071893555473167)

# %%
lasso_reg.coef_
# Out:
# array([-1.31558918, -0.86060923, -0.        ,  0.9718928 ,  0.2218634 ,
#         0.16715524,  0.18505429,  0.        ,  0.        ,  0.        ])

# %%
lasso_pred = lasso_reg.predict(x_test)
lasso_pred
# Out:
# array([30.31891798, 34.66175662, 35.99538014, 33.81222314, 33.71646026,
#        36.56647607, 35.11070156, 31.86797792, 33.41345871, 27.61306673,
#        31.06433286, 30.76520555, 33.70585247, 34.8892112 , 34.89058607,
#        35.4772496 , 34.61870902, 32.01999467, 32.73138879, 33.23828619,
#        31.25020256, 32.83577277, 29.87747047, 35.58570534, 34.28880562,
#        35.10923337, 33.98398458, 35.18303351, 33.78315523, 35.24410449,
#        29.9985733 , 22.93755657, 30.92401514, 27.86310636, 27.27690944,
#        29.09688852, 28.56851352, 31.34807909, 33.62089215, 32.29544332,
#        31.12817478, 31.75642726, 35.05401468, 34.33618519, 29.66214115,
#        30.317864  , 33.49808309, 30.40270432, 32.13941649, 26.73799291,
#        27.93106109, 35.90285525, 30.04198896, 36.96504644, 34.13403582,
#        27.91892237, 31.26801501, 29.17947223, 33.59054193, 37.20931907,
#        32.65560388, 30.67940227, 31.96266629, 32.13700361, 31.7427317 ,
# ...

# %%
plt.scatter(y_test, lasso_pred)
plt.xlabel("truth data")
plt.ylabel("predicted data")
# Out:
# Text(0, 0.5, 'predicted data')

# %%
mean_squared_error(y_test, lasso_pred)
# Out:
# 6.987940443372407

# %%
np.sqrt(mean_squared_error(y_test, elastic_pred))
# Out:
# 2.5818708488629225

# %%
mean_absolute_error(y_test, elastic_pred)
# Out:
# 2.0127668975346973

# %%
r2 = r2_score(y_test, elastic_pred)
r2
# Out:
# 0.4578540199419171

# %%
AdjR2 = 1-(1-r2)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
AdjR2
# Out:
# 0.3804045942193338
